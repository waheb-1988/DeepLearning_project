# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Example documents
documents = [
    "Andrew is a tall boy",
    "Shaji is a smart boy. Zubia is also smart"
]

# Initialize TF-IDF Vectorizer
vectorizer = TfidfVectorizer()

# Fit and transform the documents
X = vectorizer.fit_transform(documents)

# Vocabulary
print("Vocabulary:", vectorizer.get_feature_names_out())

# TF-IDF Matrix
print("TF-IDF Vectors:\n", X.toarray())
# Out:
# Vocabulary: ['also' 'andrew' 'boy' 'is' 'shaji' 'smart' 'tall' 'zubia']
# TF-IDF Vectors:
#  [[0.         0.57615236 0.40993715 0.40993715 0.         0.
#   0.57615236 0.        ]
#  [0.32391104 0.         0.23046538 0.46093075 0.32391104 0.64782209
#   0.         0.32391104]]
